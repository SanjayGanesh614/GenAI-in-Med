# %%
from preprocess import load_and_preprocess_data
from dp_at_train import train_model_with_dp_and_at
from feature_squeezing import evaluate_with_feature_squeezing
from encrypted_inference import encrypted_inference
import torch

if __name__ == "__main__":
    # Step 1: Load and preprocess data
    X_train, X_test, y_train, y_test, scaler = load_and_preprocess_data("Data/adult.csv")

    # Step 2: Train model with Adversarial Training + Differential Privacy
    model, epsilon = train_model_with_dp_and_at(X_train, y_train)

    # Step 3: Evaluate with Feature Squeezing
    print("\n[🔍] Evaluating with Feature Squeezing...")
    evaluate_with_feature_squeezing(model, X_test, y_test, scaler)

    # Step 4: Homomorphic Encryption Based Inference
    print("\n[🔐] Running Homomorphic Encrypted Inference...")
    encrypted_inference(model, X_test[:5], scaler)

    print(f"\n✅ Final Epsilon (Privacy Budget): {epsilon:.2f}")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-616197537.py in <cell line: 0>()
# ----> 1 from preprocess import load_and_preprocess_data
#       2 from dp_at_train import train_model_with_dp_and_at
#       3 from feature_squeezing import evaluate_with_feature_squeezing
#       4 from encrypted_inference import encrypted_inference
#       5 import torch
#
# ModuleNotFoundError: No module named 'preprocess'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# !pip install opacus tenseal pandas scikit-learn matplotlib torch --quiet
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 254.4/254.4 kB 10.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 35.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 5.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 116.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 88.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 53.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 86.4 MB/s eta 0:00:00

# %%
# !python /content/MODELS/main.py
# Out:
# Traceback (most recent call last):
#   File "/content/MODELS/main.py", line 18, in <module>
#     X_train, X_test, y_train, y_test, scaler = load_and_preprocess_data("data/adult.csv")
#                                                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/MODELS/preprocess.py", line 16, in load_and_preprocess_data
#     df = pd.read_csv(filepath)
#          ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pandas/io/parsers/readers.py", line 1026, in read_csv
#     return _read(filepath_or_buffer, kwds)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pandas/io/parsers/readers.py", line 620, in _read
#     parser = TextFileReader(filepath_or_buffer, **kwds)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pandas/io/parsers/readers.py", line 1620, in __init__
#     self._engine = self._make_engine(f, self.engine)
# ...

# %%
/content/drive/MyDrive/Colab Notebooks/DP AT MODEL
